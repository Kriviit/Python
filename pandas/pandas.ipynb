# %%
import pandas as pd

# %%
dir(pandas)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df=pd.DataFrame({"name":["pavan","venkat","keshava","harika"],
                "age":[20,30,40,50]})

# %%
df
# Out:
#       name  age
# 0    pavan   20
# 1   venkat   30
# 2  keshava   40
# 3   harika   50

# %%
df['name']
# Out:
# 0      pavan
# 1     venkat
# 2    keshava
# 3     harika
# Name: name, dtype: object

# %%
df.name
# Out:
# 0      pavan
# 1     venkat
# 2    keshava
# 3     harika
# Name: name, dtype: object

# %%
df=pd.read_csv('./data1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             40 non-null     int64
#  1   name                   40 non-null     object
#  2   batch                  40 non-null     object
#  3   age                    35 non-null     float64
#  4   gpa                    37 non-null     float64
#  5   attendance_percentage  40 non-null     float64
#  6   assignment_score       40 non-null     int64
#  7   exam_score             40 non-null     int64
#  8   credits_completed      39 non-null     float64
#  9   tuition_fee            39 non-null     float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 3.3+ KB

# %%
df.describe()
# Out:
#        student_id         age        gpa  attendance_percentage  \
# count   40.000000   35.000000  37.000000                40.0000
# mean    20.500000   24.714286   5.397297                78.9125
# std     11.690452   22.220250  14.274715                23.2890
# min      1.000000   19.000000   0.500000                15.8000
# 25%     10.750000   19.500000   2.800000                79.2000
# 50%     20.500000   20.000000   3.400000                87.8500
# 75%     30.250000   21.000000   3.700000                92.1750
# max     40.000000  150.000000  89.700000                98.2000
#
#        assignment_score  exam_score  credits_completed   tuition_fee
# count         40.000000   40.000000          39.000000     39.000000
# mean          72.875000   75.950000          34.846154  14064.102564
# std           24.310162   21.327664          12.656470  10022.461279
# min           12.000000   23.000000           3.000000  12000.000000
# ...

# %%
df
# Out:
#     student_id             name   batch    age   gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20.0   3.8                   95.5
# 1            2        Bob Smith  2023-A   19.0   3.2                   87.3
# 2            3      Carol Davis  2023-B   21.0   3.9                   92.1
# 3            4     David Wilson  2023-A    NaN  89.7                   82.0
# 4            5       Emma Brown  2023-B   22.0   2.1                   45.2
# 5            6     Frank Miller  2023-C   20.0   3.5                   91.8
# 6            7     Grace Taylor  2023-A   19.0   4.0                   98.2
# 7            8   Henry Anderson  2023-B  150.0   1.2                   15.8
# 8            9       Ivy Thomas  2023-C   21.0   NaN                   88.4
# 9           10     Jack Jackson  2023-A   20.0   3.7                   93.6
# 10          11       Kate White  2023-B   19.0   2.8                   78.9
# ...

# %%
df.loc[:,'name']
# Out:
# 0       Alice Johnson
# 1           Bob Smith
# 2         Carol Davis
# 3        David Wilson
# 4          Emma Brown
# 5        Frank Miller
# 6        Grace Taylor
# 7      Henry Anderson
# 8          Ivy Thomas
# 9        Jack Jackson
# 10         Kate White
# 11         Leo Harris
# 12          Mia Clark
# 13         Noah Lewis
# 14      Olivia Walker
# 15          Paul Hall
# 16        Quinn Allen
# 17         Ruby Young
# 18           Sam King
# 19        Tina Wright
# 20          Uma Lopez
# 21        Victor Hill
# 22        Wendy Green
# 23       Xavier Adams
# 24         Yara Baker
# 25       Zoe Gonzalez
# 26        Adam Nelson
# 27        Beth Carter
# 28      Carl Mitchell
# 29        Diana Perez
# 30       Eric Roberts
# 31       Fiona Turner
# 32    George Phillips
# 33    Hannah Campbell
# 34         Ian Parker
# 35        Julia Evans
# 36      Kevin Edwards
# 37       Lisa Collins
# 38       Mike Stewart
# 39       Nina Sanchez
# Name: name, dtype: object

# %%
name=df.iloc[:,1]

# %%
name
# Out:
# 0       Alice Johnson
# 1           Bob Smith
# 2         Carol Davis
# 3        David Wilson
# 4          Emma Brown
# 5        Frank Miller
# 6        Grace Taylor
# 7      Henry Anderson
# 8          Ivy Thomas
# 9        Jack Jackson
# 10         Kate White
# 11         Leo Harris
# 12          Mia Clark
# 13         Noah Lewis
# 14      Olivia Walker
# 15          Paul Hall
# 16        Quinn Allen
# 17         Ruby Young
# 18           Sam King
# 19        Tina Wright
# 20          Uma Lopez
# 21        Victor Hill
# 22        Wendy Green
# 23       Xavier Adams
# 24         Yara Baker
# 25       Zoe Gonzalez
# 26        Adam Nelson
# 27        Beth Carter
# 28      Carl Mitchell
# 29        Diana Perez
# 30       Eric Roberts
# 31       Fiona Turner
# 32    George Phillips
# 33    Hannah Campbell
# 34         Ian Parker
# 35        Julia Evans
# 36      Kevin Edwards
# 37       Lisa Collins
# 38       Mike Stewart
# 39       Nina Sanchez
# Name: name, dtype: object

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
# Out:
#     student_id             name   batch    age   gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20.0   3.8                   95.5
# 1            2        Bob Smith  2023-A   19.0   3.2                   87.3
# 2            3      Carol Davis  2023-B   21.0   3.9                   92.1
# 3            4     David Wilson  2023-A    NaN  89.7                   82.0
# 4            5       Emma Brown  2023-B   22.0   2.1                   45.2
# 5            6     Frank Miller  2023-C   20.0   3.5                   91.8
# 6            7     Grace Taylor  2023-A   19.0   4.0                   98.2
# 7            8   Henry Anderson  2023-B  150.0   1.2                   15.8
# 8            9       Ivy Thomas  2023-C   21.0   NaN                   88.4
# 9           10     Jack Jackson  2023-A   20.0   3.7                   93.6
# 10          11       Kate White  2023-B   19.0   2.8                   78.9
# ...

# %%
avg_age=df.age.mean()

# %%
# Out:
# 0      20
# 1      19
# 2      21
# 3      24
# 4      22
# 5      20
# 6      19
# 7     150
# 8      21
# 9      20
# 10     19
# 11     22
# 12     20
# 13     24
# 14     21
# 15     19
# 16     20
# 17     22
# 18     21
# 19     19
# 20     20
# 21     45
# 22     21
# 23     24
# 24     20
# 25     19
# 26     22
# 27     20
# 28     21
# 29     19
# 30     20
# 31     24
# 32     22
# 33     19
# 34     21
# 35     20
# 36     24
# 37     19
# 38     22
# 39     20
# Name: age, dtype: int32

# %%
df
# Out:
#     student_id             name   batch    age   gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20.0   3.8                   95.5
# 1            2        Bob Smith  2023-A   19.0   3.2                   87.3
# 2            3      Carol Davis  2023-B   21.0   3.9                   92.1
# 3            4     David Wilson  2023-A    NaN  89.7                   82.0
# 4            5       Emma Brown  2023-B   22.0   2.1                   45.2
# 5            6     Frank Miller  2023-C   20.0   3.5                   91.8
# 6            7     Grace Taylor  2023-A   19.0   4.0                   98.2
# 7            8   Henry Anderson  2023-B  150.0   1.2                   15.8
# 8            9       Ivy Thomas  2023-C   21.0   NaN                   88.4
# 9           10     Jack Jackson  2023-A   20.0   3.7                   93.6
# 10          11       Kate White  2023-B   19.0   2.8                   78.9
# ...

# %%
df.age=df.age.fillna(avg_age).astype(int)

# %%
df
# Out:
#     student_id             name   batch  age  gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20  3.8                   95.5
# 1            2        Bob Smith  2023-A   19  3.2                   87.3
# 2            3      Carol Davis  2023-B   21  3.9                   92.1
# 3            4     David Wilson  2023-A   24  3.9                   82.0
# 4            5       Emma Brown  2023-B   22  2.1                   45.2
# 5            6     Frank Miller  2023-C   20  3.5                   91.8
# 6            7     Grace Taylor  2023-A   19  4.0                   98.2
# 7            8   Henry Anderson  2023-B  150  1.2                   15.8
# 8            9       Ivy Thomas  2023-C   21  NaN                   88.4
# 9           10     Jack Jackson  2023-A   20  3.7                   93.6
# 10          11       Kate White  2023-B   19  2.8                   78.9
# 11          12       Leo Harris  2023-C   22  3.6                   89.5
# ...

# %%
df.credits_completed.mean()
# Out:
# 34.84615384615385

# %%
df.tuition_fee.mode()
# Out:
# 0    12000.0
# Name: tuition_fee, dtype: float64

# %%
df=df.fillna({"gpa":df.gpa.mean(),"credits_completed":df.credits_completed.mean(),'tuition_fee':df.tuition_fee.mode()[0]})

# %%
df.loc[3,'gpa']=df.gpa.mode()[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             40 non-null     int64
#  1   name                   40 non-null     object
#  2   batch                  40 non-null     object
#  3   age                    40 non-null     int32
#  4   gpa                    40 non-null     float64
#  5   attendance_percentage  40 non-null     float64
#  6   assignment_score       40 non-null     int64
#  7   exam_score             40 non-null     int64
#  8   credits_completed      40 non-null     float64
#  9   tuition_fee            40 non-null     float64
# dtypes: float64(4), int32(1), int64(3), object(2)
# memory usage: 3.1+ KB

# %%
df
# Out:
#     student_id             name   batch  age       gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20  3.800000                   95.5
# 1            2        Bob Smith  2023-A   19  3.200000                   87.3
# 2            3      Carol Davis  2023-B   21  3.900000                   92.1
# 3            4     David Wilson  2023-A   24  3.900000                   82.0
# 4            5       Emma Brown  2023-B   22  2.100000                   45.2
# 5            6     Frank Miller  2023-C   20  3.500000                   91.8
# 6            7     Grace Taylor  2023-A   19  4.000000                   98.2
# 7            8   Henry Anderson  2023-B  150  1.200000                   15.8
# 8            9       Ivy Thomas  2023-C   21  3.078378                   88.4
# 9           10     Jack Jackson  2023-A   20  3.700000                   93.6
# 10          11       Kate White  2023-B   19  2.800000                   78.9
# ...

# %%
df.age.mode()
# Out:
# 0    20
# Name: age, dtype: int32

# %%
df.age.mode()
# Out:
# 0    20
# Name: age, dtype: int32

# %%
df[df.age>25]['age']
# Out:
# 7     150
# 21     45
# Name: age, dtype: int32

# %%
df[7,'age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (7, 'age')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df[7,'age']
#
# ...

# %%
df.loc[21,'age']=20

# %%
df
# Out:
#     student_id             name   batch  age       gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20  3.800000                   95.5
# 1            2        Bob Smith  2023-A   19  3.200000                   87.3
# 2            3      Carol Davis  2023-B   21  3.900000                   92.1
# 3            4     David Wilson  2023-A   24  3.900000                   82.0
# 4            5       Emma Brown  2023-B   22  2.100000                   45.2
# 5            6     Frank Miller  2023-C   20  3.500000                   91.8
# 6            7     Grace Taylor  2023-A   19  4.000000                   98.2
# 7            8   Henry Anderson  2023-B   20  1.200000                   15.8
# 8            9       Ivy Thomas  2023-C   21  3.078378                   88.4
# 9           10     Jack Jackson  2023-A   20  3.700000                   93.6
# 10          11       Kate White  2023-B   19  2.800000                   78.9
# ...

# %%
df.to_json('transformed_data.json')

# %%
df=pd.read_csv('data1.csv')

# %%
df
# Out:
#     student_id             name   batch    age   gpa  attendance_percentage  \
# 0          NaN             None    None    NaN   NaN                    NaN
# 1          2.0        Bob Smith  2023-A   19.0   3.2                   87.3
# 2          3.0      Carol Davis  2023-B   21.0   3.9                   92.1
# 3          4.0     David Wilson  2023-A    NaN  89.7                   82.0
# 4          5.0       Emma Brown  2023-B   22.0   2.1                   45.2
# 5          6.0     Frank Miller  2023-C   20.0   3.5                   91.8
# 6          7.0     Grace Taylor  2023-A   19.0   4.0                   98.2
# 7          8.0   Henry Anderson  2023-B  150.0   1.2                   15.8
# 8          9.0       Ivy Thomas  2023-C   21.0   NaN                   88.4
# 9         10.0     Jack Jackson  2023-A   20.0   3.7                   93.6
# 10        11.0       Kate White  2023-B   19.0   2.8                   78.9
# ...

# %%
df
# Out:
#     student_id             name   batch    age   gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A    NaN   NaN                    NaN
# 1            2        Bob Smith  2023-A   19.0   3.2                   87.3
# 2            3      Carol Davis  2023-B   21.0   3.9                   92.1
# 3            4     David Wilson  2023-A    NaN  89.7                   82.0
# 4            5       Emma Brown  2023-B   22.0   2.1                   45.2
# 5            6     Frank Miller  2023-C   20.0   3.5                   91.8
# 6            7     Grace Taylor  2023-A   19.0   4.0                   98.2
# 7            8   Henry Anderson  2023-B  150.0   1.2                   15.8
# 8            9       Ivy Thomas  2023-C   21.0   NaN                   88.4
# 9           10     Jack Jackson  2023-A   20.0   3.7                   93.6
# 10          11       Kate White  2023-B   19.0   2.8                   78.9
# ...

# %%
df.iloc[0,:7]=None

# %%
df.dropna(axis=1)
# Out:
#     exam_score
# 0           92
# 1           84
# 2           89
# 3           35
# 4           41
# 5           87
# 6           98
# 7           23
# 8           86
# 9           91
# 10          72
# 11          85
# 12          81
# 13          94
# 14          77
# 15          35
# 16          93
# 17          89
# 18          83
# 19          74
# 20          88
# 21          42
# 22          86
# 23          79
# 24          95
# 25          66
# 26          84
# 27          88
# 28          90
# 29          29
# 30          92
# 31          70
# 32          87
# 33          80
# 34          96
# 35          63
# 36          89
# 37          82
# 38          31
# 39          92

# %%
df.drop('age',axis=1)
# Out:
#     student_id             name   batch   gpa  attendance_percentage  \
# 0          NaN             None    None   NaN                    NaN
# 1          2.0        Bob Smith  2023-A   3.2                   87.3
# 2          3.0      Carol Davis  2023-B   3.9                   92.1
# 3          4.0     David Wilson  2023-A  89.7                   82.0
# 4          5.0       Emma Brown  2023-B   2.1                   45.2
# 5          6.0     Frank Miller  2023-C   3.5                   91.8
# 6          7.0     Grace Taylor  2023-A   4.0                   98.2
# 7          8.0   Henry Anderson  2023-B   1.2                   15.8
# 8          9.0       Ivy Thomas  2023-C   NaN                   88.4
# 9         10.0     Jack Jackson  2023-A   3.7                   93.6
# 10        11.0       Kate White  2023-B   2.8                   78.9
# 11        12.0       Leo Harris  2023-C   3.6                   89.5
# 12        13.0        Mia Clark  2023-A   3.4                   85.7
# ...

# %%
df1=pd.read_csv('./data1.csv')

# %%
df2=pd.read_csv('./data2.csv')

# %%
df1
# Out:
#     student_id             name   batch    age   gpa  attendance_percentage  \
# 0            1    Alice Johnson  2023-A   20.0   3.8                   95.5
# 1            2        Bob Smith  2023-A   19.0   3.2                   87.3
# 2            3      Carol Davis  2023-B   21.0   3.9                   92.1
# 3            4     David Wilson  2023-A    NaN  89.7                   82.0
# 4            5       Emma Brown  2023-B   22.0   2.1                   45.2
# 5            6     Frank Miller  2023-C   20.0   3.5                   91.8
# 6            7     Grace Taylor  2023-A   19.0   4.0                   98.2
# 7            8   Henry Anderson  2023-B  150.0   1.2                   15.8
# 8            9       Ivy Thomas  2023-C   21.0   NaN                   88.4
# 9           10     Jack Jackson  2023-A   20.0   3.7                   93.6
# 10          11       Kate White  2023-B   19.0   2.8                   78.9
# ...

# %%
df2
# Out:
#     student_id course_code                  course_name     instructor  \
# 0            1       CS101  Introduction to Programming      Dr. Smith
# 1            1     MATH201                  Calculus II  Prof. Johnson
# 2            1      ENG101          English Composition      Dr. Davis
# 3            2       CS101  Introduction to Programming      Dr. Smith
# 4            2     MATH101                   Calculus I   Prof. Wilson
# 5            3       CS101  Introduction to Programming      Dr. Smith
# 6            3     MATH201                  Calculus II  Prof. Johnson
# 7            3     PHYS101                    Physics I      Dr. Brown
# 8            5       CS101  Introduction to Programming      Dr. Smith
# 9            5     MATH101                   Calculus I   Prof. Wilson
# 10           7       CS101  Introduction to Programming      Dr. Smith
# 11           7     MATH201                  Calculus II  Prof. Johnson
# ...

# %%
pd.merge(df1,df2,on='student_id',how='inner')
# Out:
#     student_id            name   batch    age  gpa  attendance_percentage  \
# 0            1   Alice Johnson  2023-A   20.0  3.8                   95.5
# 1            1   Alice Johnson  2023-A   20.0  3.8                   95.5
# 2            1   Alice Johnson  2023-A   20.0  3.8                   95.5
# 3            2       Bob Smith  2023-A   19.0  3.2                   87.3
# 4            2       Bob Smith  2023-A   19.0  3.2                   87.3
# 5            3     Carol Davis  2023-B   21.0  3.9                   92.1
# 6            3     Carol Davis  2023-B   21.0  3.9                   92.1
# 7            3     Carol Davis  2023-B   21.0  3.9                   92.1
# 8            5      Emma Brown  2023-B   22.0  2.1                   45.2
# 9            5      Emma Brown  2023-B   22.0  2.1                   45.2
# 10           7    Grace Taylor  2023-A   19.0  4.0                   98.2
# 11           7    Grace Taylor  2023-A   19.0  4.0                   98.2
# ...

# %%
pd.merge(df1,df2,on='student_id',how='left').tail(10)
# Out:
#     student_id             name   batch   age  gpa  attendance_percentage  \
# 52          34  Hannah Campbell  2023-A  19.0  3.1                   83.4
# 53          35       Ian Parker  2023-B  21.0  3.9                   97.1
# 54          35       Ian Parker  2023-B  21.0  3.9                   97.1
# 55          35       Ian Parker  2023-B  21.0  3.9                   97.1
# 56          36      Julia Evans  2023-C  20.0  2.3                   68.2
# 57          37    Kevin Edwards  2023-A   NaN  3.6                   91.5
# 58          38     Lisa Collins  2023-B  19.0  3.2                   85.3
# 59          39     Mike Stewart  2023-C  22.0  0.8                   22.1
# 60          40     Nina Sanchez  2023-A  20.0  3.7                   93.8
# 61          40     Nina Sanchez  2023-A  20.0  3.7                   93.8
#
#     assignment_score  exam_score  credits_completed  tuition_fee course_code  \
# ...

# %%
pd.merge(df1,df2,on='student_id',how='left').tail()
# Out:
#     student_id           name   batch   age  gpa  attendance_percentage  \
# 57          37  Kevin Edwards  2023-A   NaN  3.6                   91.5
# 58          38   Lisa Collins  2023-B  19.0  3.2                   85.3
# 59          39   Mike Stewart  2023-C  22.0  0.8                   22.1
# 60          40   Nina Sanchez  2023-A  20.0  3.7                   93.8
# 61          40   Nina Sanchez  2023-A  20.0  3.7                   93.8
#
#     assignment_score  exam_score  credits_completed  tuition_fee course_code  \
# 57                88          89               42.0      12000.0         NaN
# 58                78          82               37.0      12500.0         NaN
# 59                20          31                7.0      13000.0       CS101
# 60                90          92               44.0      12000.0       CS101
# 61                90          92               44.0      12000.0     MATH201
#
# ...

# %%
pd.merge(df1,df2,on='student_id',how='right')
# Out:
#     student_id            name   batch    age  gpa  attendance_percentage  \
# 0            1   Alice Johnson  2023-A   20.0  3.8                   95.5
# 1            1   Alice Johnson  2023-A   20.0  3.8                   95.5
# 2            1   Alice Johnson  2023-A   20.0  3.8                   95.5
# 3            2       Bob Smith  2023-A   19.0  3.2                   87.3
# 4            2       Bob Smith  2023-A   19.0  3.2                   87.3
# 5            3     Carol Davis  2023-B   21.0  3.9                   92.1
# 6            3     Carol Davis  2023-B   21.0  3.9                   92.1
# 7            3     Carol Davis  2023-B   21.0  3.9                   92.1
# 8            5      Emma Brown  2023-B   22.0  2.1                   45.2
# 9            5      Emma Brown  2023-B   22.0  2.1                   45.2
# 10           7    Grace Taylor  2023-A   19.0  4.0                   98.2
# 11           7    Grace Taylor  2023-A   19.0  4.0                   98.2
# ...

# %%
df=pd.read_csv('groupby.csv')

# %%
df.head(30)
# Out:
#     student_id course_code                  course_name     instructor  \
# 0            1       CS101  Introduction to Programming      Dr. Smith
# 1            1     MATH201                  Calculus II  Prof. Johnson
# 2            1      ENG101          English Composition      Dr. Davis
# 3            2       CS101  Introduction to Programming      Dr. Smith
# 4            2     MATH101                   Calculus I   Prof. Wilson
# 5            3       CS101  Introduction to Programming      Dr. Smith
# 6            3     MATH201                  Calculus II  Prof. Johnson
# 7            3     PHYS101                    Physics I      Dr. Brown
# 8            5       CS101  Introduction to Programming      Dr. Smith
# 9            5     MATH101                   Calculus I   Prof. Wilson
# 10           7       CS101  Introduction to Programming      Dr. Smith
# 11           7     MATH201                  Calculus II  Prof. Johnson
# ...

# %%
df.groupby('instructor')['credit_hours'].max()
# Out:
# instructor
# Dr. Anderson     3
# Dr. Brown        4
# Dr. Davis        3
# Dr. Lee          3
# Dr. Smith        3
# Dr. Taylor       4
# Prof. Garcia     3
# Prof. Johnson    4
# Prof. Miller     3
# Prof. White      3
# Prof. Wilson     4
# Name: credit_hours, dtype: int64

# %%
df.credit_hours.max()
# Out:
# 4
